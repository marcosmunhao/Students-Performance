# %% [markdown]
# # Students Performance

# %% [markdown]
# ### Importing packages and our data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
studentsperformance = pd.read_csv("StudentsPerformance.csv")
print('We have data for {} students.'.format(len(studentsperformance)))
studentsperformance.head(5)
# Out:
# We have data for 1000 students.
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ### Variables:
# <ul style='font-size: 18px; line-height: 2; text-align: justify;'>
#     <li><b>Gender</b> - Students' genders</li>
#     <li><b>Parental level of education</b> - How much students' parents studied</li>
#     <li><b>Race/Ethnicity</b> - Ethnic groups of the students</li>
#     <li><b>Lunch</b> - Kind of lunch that students usually get</li>
#     <li><b>Test preparation course</b> - Level of preparation course</li>
#     <li><b>Math score</b> - Score in Math </li>
#     <li><b>Writing score</b> - Score in Writing</li>
#     <li><b>Reading score</b> - Score in Reading</li>
# </ul>

# %% [markdown]
# ### Let's see how many genders are in this data

# %%
genders = studentsperformance.gender.value_counts()
g = genders.to_frame()
g.reset_index(inplace=True)
g.columns = ["gender", "quant"]
print('We have in this data {} genders: '.format(len(g)))
for i in range(len(g)):
    print(g.gender.values[i])
# Out:
# We have in this data 2 genders:
# female
# male

# %%
#setting the style and colors of plots

sns.set_theme(style='darkgrid', palette='dark')

# plotting
ax = sns.barplot(data=g, x="gender", y="quant")
ax.set_title('Students\' genders', fontsize=18)
ax.set_ylabel('Quantity', fontsize=14)
ax.set_xlabel(None)
plt.show()

# %% [markdown]
# ### Looking at race/ethnicity and splitting them by gender

# %% [markdown]
# ##### I'll call race/ethnicity just as race

# %%
race = pd.crosstab(index=studentsperformance["race/ethnicity"], columns=studentsperformance.gender)
race.reset_index(inplace=True)
race.index.name = None
race.columns = ["Race", "female", "male"]
race.sort_values(by='Race', inplace=True)
race["total"] = race["female"] + race["male"]
print('We have a total of {} races, which are: '.format(len(race)))
for i in range(len(race)):
    print(race.Race.values[i])
# Out:
# We have a total of 5 races, which are:
# group A
# group B
# group C
# group D
# group E

# %%
ax = sns.barplot(data=race, x='Race', y='total')
ax.set_title('Race/Ethnicity students\' distribution', fontsize=18)
ax.set_xlabel(None)
ax.set_ylabel('Total', fontsize=14)
plt.show()

# %% [markdown]
# ##### Splitting by gender

# %%
plt.bar(race.Race, height=race.female, width=0.4, label='Female', align='edge')
plt.bar(race.Race, height=race.male, width=-0.4, label='Male', align='edge')
plt.legend()
plt.show()

# %%
parental_education = studentsperformance['parental level of education'].value_counts()
parental_education = parental_education.to_frame()
parental_education.reset_index(inplace=True)
parental_education.columns = ['Parental level of education', 'Quantity']
print('We have in this data {} levels of parental education: '.format(len(parental_education)))
for i in range(len(parental_education)):
    print(parental_education['Parental level of education'].values[i])
# Out:
# We have in this data 6 levels of parental education:
# some college
# associate's degree
# high school
# some high school
# bachelor's degree
# master's degree

# %%
ax = sns.barplot(data=parental_education.sort_values(by='Quantity'), x='Quantity', y='Parental level of education')
ax.set_title('Students\' parental levels of education', fontsize=18)
ax.set_ylabel(None)
plt.show()

# %%
lunch = studentsperformance['lunch'].value_counts()
lunch = lunch.to_frame()
lunch.reset_index(inplace=True)
lunch.columns = ['Kind of lunch', 'Quantity']
print('We have in this data {} kinds of lunch: '.format(len(lunch)))
for i in range(len(lunch)):
    print(lunch['Kind of lunch'].values[i])
# Out:
# We have in this data 2 kinds of lunch:
# standard
# free/reduced

# %%
ax = sns.barplot(data=lunch, x='Kind of lunch', y='Quantity')
ax.figure.set_size_inches(10,4)
ax.set_title('Students\' lunch', fontsize=18)
ax.set_ylabel('Quantity', fontsize=16)
ax.set_xlabel(None)
plt.show()

# %%
test = studentsperformance['test preparation course'].value_counts()
test = test.to_frame()
test.reset_index(inplace=True)
test.columns = ['Test', 'Quantity']
print('We have in this data {} levels of tests: '.format(len(test)))
for i in range(len(test)):
    print(test['Test'].values[i])
# Out:
# We have in this data 2 kinds of tests:
# none
# completed

# %%
ax = sns.barplot(data=test, x='Test', y='Quantity')
ax.figure.set_size_inches(8,6)
ax.set_title('Students\' test preparation course', fontsize=18)
ax.set_ylabel('Quantity', fontsize=16)
ax.set_xlabel(None)
plt.show()

# %% [markdown]
# ## Vamos observar as estatísticas descritivas
#
# ### Inicialmente: Média, desvio padrão, mínimo e máximo

# %%
desc = studentsperformance.describe().round(2)
desc = desc.drop(['count', '25%', '50%', '75%'])
desc
# Out:
#       math score  reading score  writing score
# mean       66.09          69.17          68.05
# std        15.16          14.60          15.20
# min         0.00          17.00          10.00
# max       100.00         100.00         100.00

# %% [markdown]
# ### Os quartis vamos ver nos boxplots

# %%
ax = sns.boxplot(data=studentsperformance[['math score','reading score', 'writing score']])

# %% [markdown]
# ###### E esses outliers? Porque? Precisamos investigar!
#
# ##### A maiora das notas está entre 55 e 80.

# %%
# um artificio para poder observar a distribuição em um scatter plot vai variar de 0 a 100
studentsperformance['ones'] = np.linspace(start=0.0,stop=100.0, num=1000)
studentsperformance.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score    ones
# 0                    none          72             72             74  0.0000
# 1               completed          69             90             88  0.1001
# 2                    none          90             95             93  0.2002
# 3                    none          47             57             44  0.3003
# 4                    none          76             78             75  0.4004

# %%
ax = sns.displot(data=studentsperformance, x='math score', hue='gender', kind='kde')
plt.show()

# %% [markdown]
# ### Agora vamos observar o desempenho desses grupos
